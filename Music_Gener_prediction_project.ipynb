# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')
dset=pd.read_csv("dataset.csv")

# %%
dset.shape
# Out:
# (1000, 28)

# %%
dset.ndim
type(dset)
# Out:
# pandas.core.frame.DataFrame

# %%
dset.head()
# Out:
#           filename  chroma_stft      rmse  spectral_centroid  \
# 0  blues.00000.wav     0.349943  0.130225        1784.420446
# 1  blues.00001.wav     0.340983  0.095918        1529.835316
# 2  blues.00002.wav     0.363603  0.175573        1552.481958
# 3  blues.00003.wav     0.404779  0.141191        1070.119953
# 4  blues.00004.wav     0.308590  0.091563        1835.494603
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0         2002.650192  3806.485316            0.083066 -113.596748
# 1         2038.617579  3548.820207            0.056044 -207.556793
# 2         1747.165985  3040.514948            0.076301  -90.754387
# 3         1596.333948  2185.028454            0.033309 -199.431152
# 4         1748.362448  3580.945013            0.101500 -160.266037
#
#         mfcc2      mfcc3  ...    mfcc12    mfcc13    mfcc14    mfcc15  \
# 0  121.557297 -19.158825  ...  8.810669 -3.667368  5.751691 -5.162763
# ...

# %%
dset.tail()
# Out:
#            filename  chroma_stft      rmse  spectral_centroid  \
# 995  rock.00095.wav     0.351991  0.079469        2008.581132
# 996  rock.00096.wav     0.398653  0.076452        2006.051164
# 997  rock.00097.wav     0.432103  0.081617        2077.190361
# 998  rock.00098.wav     0.362349  0.083888        1398.672358
# 999  rock.00099.wav     0.358195  0.054461        1609.442919
#
#      spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 995         2106.617024  4254.215942            0.089267 -153.632309
# 996         2068.327905  4147.374921            0.097659 -142.424210
# 997         1926.989678  4030.767293            0.121824 -125.031311
# 998         1818.148469  3014.740104            0.048731 -224.972305
# 999         1797.065098  3246.280370            0.076290 -235.189331
#
#           mfcc2      mfcc3  ...     mfcc12     mfcc13    mfcc14     mfcc15  \
# 995  109.857262 -23.085709  ...  12.350816 -12.306271  5.780973 -10.279924
# ...

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            1000 non-null   object
#  1   chroma_stft         1000 non-null   float64
#  2   rmse                1000 non-null   float64
#  3   spectral_centroid   1000 non-null   float64
#  4   spectral_bandwidth  1000 non-null   float64
#  5   rolloff             1000 non-null   float64
#  6   zero_crossing_rate  1000 non-null   float64
#  7   mfcc1               1000 non-null   float64
#  8   mfcc2               1000 non-null   float64
#  9   mfcc3               1000 non-null   float64
#  10  mfcc4               1000 non-null   float64
#  11  mfcc5               1000 non-null   float64
#  12  mfcc6               1000 non-null   float64
#  13  mfcc7               1000 non-null   float64
#  14  mfcc8               1000 non-null   float64
# ...

# %%
dset.isnull().sum()
# Out:
# filename              0
# chroma_stft           0
# rmse                  0
# spectral_centroid     0
# spectral_bandwidth    0
# rolloff               0
# zero_crossing_rate    0
# mfcc1                 0
# mfcc2                 0
# mfcc3                 0
# mfcc4                 0
# mfcc5                 0
# mfcc6                 0
# mfcc7                 0
# mfcc8                 0
# mfcc9                 0
# mfcc10                0
# mfcc11                0
# mfcc12                0
# mfcc13                0
# mfcc14                0
# mfcc15                0
# mfcc16                0
# mfcc17                0
# mfcc18                0
# mfcc19                0
# mfcc20                0
# label                 0
# dtype: int64

# %%
dset.value_counts("label")
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# dtype: int64

# %%
dset.groupby("mfcc15").mean()
# Out:
#             chroma_stft      rmse  spectral_centroid  spectral_bandwidth  \
# mfcc15
# -17.545473     0.429511  0.148366        1739.019621         2290.401739
# -17.283947     0.395817  0.112021        2292.322766         2149.110049
# -16.991062     0.386951  0.129172        2390.772194         2463.394088
# -16.485552     0.397725  0.134892        2272.495079         2356.855937
# -16.089144     0.484546  0.138283        2871.235641         2126.925662
# ...                 ...       ...                ...                 ...
#  7.896713      0.473491  0.179493        2567.551058         2630.174239
#  7.983838      0.477079  0.195810        2538.855932         2644.407237
#  9.959834      0.217320  0.035139        2423.392871         1884.700007
#  10.536645     0.369008  0.013996        1424.013746         1696.938576
#  12.357588     0.227545  0.013566        1800.707843         1780.942269
#
#                 rolloff  zero_crossing_rate       mfcc1       mfcc2  \
# mfcc15
# ...

# %%
dset.groupby("mfcc2").std()
# Out:
#              chroma_stft  rmse  spectral_centroid  spectral_bandwidth  \
# mfcc2
# -1.527147            NaN   NaN                NaN                 NaN
#  16.381897           NaN   NaN                NaN                 NaN
#  22.763885           NaN   NaN                NaN                 NaN
#  30.574678           NaN   NaN                NaN                 NaN
#  30.600363           NaN   NaN                NaN                 NaN
# ...                  ...   ...                ...                 ...
#  181.600647          NaN   NaN                NaN                 NaN
#  182.544434          NaN   NaN                NaN                 NaN
#  190.198074          NaN   NaN                NaN                 NaN
#  190.791962          NaN   NaN                NaN                 NaN
#  193.096512          NaN   NaN                NaN                 NaN
#
#              rolloff  zero_crossing_rate  mfcc1  mfcc3  mfcc4  mfcc5  ...  \
# ...

# %%
dset.std()
# Out:
# chroma_stft              0.081706
# rmse                     0.065685
# spectral_centroid      715.961347
# spectral_bandwidth     526.337663
# rolloff               1574.770035
# zero_crossing_rate       0.041834
# mfcc1                  100.235659
# mfcc2                   31.331904
# mfcc3                   21.695015
# mfcc4                   16.666986
# mfcc5                   12.222554
# mfcc6                   11.840801
# mfcc7                    9.941638
# mfcc8                   10.464090
# mfcc9                    8.284181
# mfcc10                   7.937977
# mfcc11                   6.819018
# mfcc12                   6.717312
# mfcc13                   6.170919
# mfcc14                   5.009489
# mfcc15                   4.874423
# mfcc16                   4.579110
# mfcc17                   4.550650
# mfcc18                   3.869088
# mfcc19                   3.755574
# mfcc20                   3.837561
# dtype: float64

# %%
dset.mean()
# Out:
# chroma_stft              0.378669
# rmse                     0.130929
# spectral_centroid     2201.834226
# spectral_bandwidth    2242.559613
# rolloff               4571.702159
# zero_crossing_rate       0.103637
# mfcc1                 -144.479170
# mfcc2                   99.552199
# mfcc3                   -8.921949
# mfcc4                   36.293061
# mfcc5                   -1.146627
# mfcc6                   14.634082
# mfcc7                   -5.129624
# mfcc8                   10.119876
# mfcc9                   -6.995751
# mfcc10                   7.730250
# mfcc11                  -6.021121
# mfcc12                   4.471604
# mfcc13                  -4.797232
# mfcc14                   1.781547
# mfcc15                  -3.870276
# mfcc16                   1.147988
# mfcc17                  -3.967431
# mfcc18                   0.507303
# mfcc19                  -2.328779
# mfcc20                  -1.094875
# dtype: float64

# %%
dset.describe()
# Out:
#        chroma_stft         rmse  spectral_centroid  spectral_bandwidth  \
# count  1000.000000  1000.000000        1000.000000         1000.000000
# mean      0.378669     0.130929        2201.834226         2242.559613
# std       0.081706     0.065685         715.961347          526.337663
# min       0.171782     0.005276         569.930721          897.994319
# 25%       0.319641     0.086625        1627.793931         1907.136505
# 50%       0.383075     0.122448        2209.468780         2221.408983
# 75%       0.435974     0.175793        2691.969702         2578.474352
# max       0.663573     0.398012        4434.439444         3509.578677
#
#            rolloff  zero_crossing_rate        mfcc1        mfcc2        mfcc3  \
# count  1000.000000         1000.000000  1000.000000  1000.000000  1000.000000
# mean   4571.702159            0.103637  -144.479170    99.552199    -8.921949
# std    1574.770035            0.041834   100.235659    31.331904    21.695015
# ...

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\SWETHA K\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
dset['label'].value_counts()
# Out:
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: label, dtype: int64

# %%
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(dset['label'])

# %%
label_encode = LabelEncoder()

# %%
lable = label_encode.fit_transform(dset['label'])

# %%
dset['label'] = labels

# %%
dset.head
# Out:
# <bound method NDFrame.head of             filename  chroma_stft      rmse  spectral_centroid  \
# 0    blues.00000.wav     0.349943  0.130225        1784.420446
# 1    blues.00001.wav     0.340983  0.095918        1529.835316
# 2    blues.00002.wav     0.363603  0.175573        1552.481958
# 3    blues.00003.wav     0.404779  0.141191        1070.119953
# 4    blues.00004.wav     0.308590  0.091563        1835.494603
# ..               ...          ...       ...                ...
# 995   rock.00095.wav     0.351991  0.079469        2008.581132
# 996   rock.00096.wav     0.398653  0.076452        2006.051164
# 997   rock.00097.wav     0.432103  0.081617        2077.190361
# 998   rock.00098.wav     0.362349  0.083888        1398.672358
# 999   rock.00099.wav     0.358195  0.054461        1609.442919
#
#      spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0           2002.650192  3806.485316            0.083066 -113.596748
# ...

# %%
dset['label'].value_counts()
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# 5    100
# 6    100
# 7    100
# 8    100
# 9    100
# Name: label, dtype: int64

# %%
dset=dset.drop("filename",axis=1)
x=dset.drop("label",axis=1)
y=dset['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, stratify=y, random_state=3 )

# %%
print(dset.std())
# Out:
# chroma_stft              0.081706
# rmse                     0.065685
# spectral_centroid      715.961347
# spectral_bandwidth     526.337663
# rolloff               1574.770035
# zero_crossing_rate       0.041834
# mfcc1                  100.235659
# mfcc2                   31.331904
# mfcc3                   21.695015
# mfcc4                   16.666986
# mfcc5                   12.222554
# mfcc6                   11.840801
# mfcc7                    9.941638
# mfcc8                   10.464090
# mfcc9                    8.284181
# mfcc10                   7.937977
# mfcc11                   6.819018
# mfcc12                   6.717312
# mfcc13                   6.170919
# mfcc14                   5.009489
# mfcc15                   4.874423
# mfcc16                   4.579110
# mfcc17                   4.550650
# mfcc18                   3.869088
# mfcc19                   3.755574
# mfcc20                   3.837561
# label                    2.873719
# dtype: float64

# %%
scaler= StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_standardized = scaler.transform(x_train)

# %%
print(x_train_standardized)
# Out:
# [[ 0.37226501  0.74109247  1.51033733 ... -0.97540394 -0.00715411
#   -0.25370934]
#  [-1.6021767  -0.74828489 -1.22361623 ... -0.52401941  1.51743364
#   -0.05299852]
#  [-0.12093317 -0.44750912 -0.72084957 ...  1.06574673 -0.21252528
#    0.21084555]
#  ...
#  [-0.27410021  0.64401141 -0.07030452 ... -0.9139241   0.32483425
#   -0.09364722]
#  [ 0.46312712 -0.59920677  0.4011512  ...  1.30186343  1.47489928
#    0.93800511]
#  [-1.02408088 -0.28090389  0.30612052 ... -1.0210127   0.41454986
#   -0.278548  ]]

# %%
print(x_train_standardized.std())
# Out:
# 1.0

# %%
x_test_standardized = scaler.transform(x_test)

# %%
print(x_test_standardized.std())
# Out:
# 1.0003167301423626

# %%
clas=svm.SVC(kernel="linear")

# %%
clas.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
xtrain_prediction= clas.predict(x_train)

# %%
trainingdata_accuracy = accuracy_score(xtrain_prediction, y_train)

# %%
print("accuracy score train",trainingdata_accuracy)
# Out:
# accuracy score train 0.76

# %%
xtest_prediction= clas.predict(x_test)
testdata_accuracy = accuracy_score(xtest_prediction, y_test)
print("accuracy score test",testdata_accuracy)
# Out:
# accuracy score test 0.56

# %%
input_data=(0.429974586,0.088072859,2389.388002,2027.322117,4448.231435,0.144281818,93.36763763,93.36763763,-52.39792252,59.22017288,20.94338226,20.94338226,-6.523478508,21.8909874,-18.96372795,17.0484314,-15.88138199,11.08149624,-18.48351097,-0.826451182,-5.617232323,4.660636425,-8.736258507,2.113764286,-8.560464859,0.212518439
)

# %%
input_data_as_numpy_array = np.asarray(input_data)

# %%
input_data_reshaped= input_data_as_numpy_array.reshape(1,-1)

# %%
std_data= scaler.transform(input_data_reshaped)
print(std_data)
# Out:
# [[ 0.62724164 -0.65974888  0.26998822 -0.40645763 -0.07563692  0.98562938
#    2.39826013 -0.20050928 -1.99210663  1.35881698  1.79963504  0.53421735
#   -0.13902744  1.11337476 -1.45939624  1.17479157 -1.44921815  0.98886606
#   -2.21572288 -0.49382949 -0.34439611  0.77760381 -1.02161317  0.44237437
#   -1.65423185  0.34902415]]

# %%
prediction=clas.predict(std_data)
print(prediction)
# Out:
# [0]

# %%
if(prediction[0]==0):
    print("The gener of music is blues")
elif(prediction[1]==1):
    print("The gener of music is classical")
elif(prediction[2]==2):
    print("The gener of music is country")
elif(prediction[3]==3):
    print("The gener of music is disco")
elif(prediction[4]==4):
    print("The gener of music is hiphop")
elif(prediction[5]==5):
    print("The gener of music is jazz")
elif(prediction[6]==6):
    print("The gener of music is metal")
elif(prediction[7]==7):
    print("The gener of music is pop")
elif(prediction[8]==8):
    print("The gener of music is reggae")
elif(prediction[9]==9):
    print("The gener of music is rock")
else:
    print("provide correct data")
# Out:
# The gener of music is blues

# %%
print("accuracy score train",trainingdata_accuracy)
